# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import glob
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

# %%
data=[]
labels=[]

for i, item in enumerate(glob.glob("/content/drive/MyDrive/parkinson-new//*//*")):
    img=cv2.imread(item)
    r_img=cv2.resize(img,(224,224))
    data.append(r_img)
    label=item.split("/")[-2]
    labels.append(label)
    if i % 10 ==0:
      print("[INFO] {}/130 processesd".format(i))
data = np.array(data)/255
le = LabelEncoder()
labels=le.fit_transform(labels)
labels=to_categorical(labels)


X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.25)
baseModel=VGG16(include_top= False,
                weights="imagenet",
                input_tensor=layers.Input(shape=(224,224,3)))
net=models.Sequential([baseModel,
                      layers.MaxPooling2D(pool_size=(4,4)),
                      layers.Flatten(),
                      layers.Dense(64,activation="relu"),
                      layers.Dense(2,activation="softmax")
                      ])
for layer in baseModel.layers:
  layer.trainable= False
opt=Adam(learning_rate=0.01,
        decay=0.01/10,
        )
net.compile(optimizer=opt,
            loss="binary_crossentropy",
            metrics=["accuracy"])
H=net.fit(X_train,y_train,epochs = 40, batch_size= 8,validation_data = (X_test,y_test))
plt.style.use("ggplot")
plt.plot(H.history["accuracy"],label="train")
plt.plot(H.history["val_accuracy"],label="test")
plt.plot(H.history["loss"],label="train loss")
plt.plot(H.history["val_loss"],label="test loss")
plt.legend()
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.title("Parkinson classification")
plt.show()
# Out:
# [INFO] 0/130 processesd
# [INFO] 10/130 processesd
# [INFO] 20/130 processesd
# [INFO] 30/130 processesd
# [INFO] 40/130 processesd
# [INFO] 50/130 processesd
# [INFO] 60/130 processesd
# [INFO] 70/130 processesd
# [INFO] 80/130 processesd
# [INFO] 90/130 processesd
# [INFO] 100/130 processesd
# [INFO] 110/130 processesd
# [INFO] 120/130 processesd
# Epoch 1/40
# 12/12 [==============================] - 3s 182ms/step - loss: 0.9103 - accuracy: 0.5054 - val_loss: 0.8240 - val_accuracy: 0.5806
# Epoch 2/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.7527 - accuracy: 0.4946 - val_loss: 0.6619 - val_accuracy: 0.7419
# Epoch 3/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.6108 - accuracy: 0.7312 - val_loss: 0.6088 - val_accuracy: 0.6452
# Epoch 4/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.5732 - accuracy: 0.8280 - val_loss: 0.5728 - val_accuracy: 0.6774
# Epoch 5/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.5450 - accuracy: 0.7742 - val_loss: 0.5464 - val_accuracy: 0.8387
# Epoch 6/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.5038 - accuracy: 0.7957 - val_loss: 0.5140 - val_accuracy: 0.8387
# Epoch 7/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.4086 - accuracy: 0.9140 - val_loss: 0.4716 - val_accuracy: 0.8710
# Epoch 8/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.3690 - accuracy: 0.8602 - val_loss: 0.4720 - val_accuracy: 0.8387
# Epoch 9/40
# 12/12 [==============================] - 2s 148ms/step - loss: 0.3783 - accuracy: 0.8602 - val_loss: 0.5948 - val_accuracy: 0.6452
# Epoch 10/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.3035 - accuracy: 0.8925 - val_loss: 0.4228 - val_accuracy: 0.8065
# Epoch 11/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.2447 - accuracy: 0.9247 - val_loss: 0.4247 - val_accuracy: 0.9032
# Epoch 12/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.2162 - accuracy: 0.9462 - val_loss: 0.3716 - val_accuracy: 0.8387
# Epoch 13/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.2421 - accuracy: 0.9140 - val_loss: 0.3616 - val_accuracy: 0.8387
# Epoch 14/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.1948 - accuracy: 0.9462 - val_loss: 0.3450 - val_accuracy: 0.8710
# Epoch 15/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.1533 - accuracy: 0.9785 - val_loss: 0.3477 - val_accuracy: 0.8387
# Epoch 16/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.1301 - accuracy: 0.9785 - val_loss: 0.3290 - val_accuracy: 0.8387
# Epoch 17/40
# 12/12 [==============================] - 2s 169ms/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.3557 - val_accuracy: 0.8387
# Epoch 18/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.1201 - accuracy: 0.9677 - val_loss: 0.3220 - val_accuracy: 0.8710
# Epoch 19/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0854 - accuracy: 0.9892 - val_loss: 0.2882 - val_accuracy: 0.8710
# Epoch 20/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0787 - accuracy: 0.9892 - val_loss: 0.2665 - val_accuracy: 0.8710
# Epoch 21/40
# 12/12 [==============================] - 2s 149ms/step - loss: 0.0915 - accuracy: 0.9892 - val_loss: 0.2662 - val_accuracy: 0.8710
# Epoch 22/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.2889 - val_accuracy: 0.8387
# Epoch 23/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.2529 - val_accuracy: 0.8710
# Epoch 24/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 0.2521 - val_accuracy: 0.8710
# Epoch 25/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.3168 - val_accuracy: 0.8387
# Epoch 26/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0597 - accuracy: 0.9785 - val_loss: 0.2949 - val_accuracy: 0.9032
# Epoch 27/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.3059 - val_accuracy: 0.8710
# Epoch 28/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.8710
# Epoch 29/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.8710
# Epoch 30/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.8710
# Epoch 31/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.2567 - val_accuracy: 0.8710
# Epoch 32/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.9032
# Epoch 33/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.8387
# Epoch 34/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.8710
# Epoch 35/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.8710
# Epoch 36/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.2938 - val_accuracy: 0.8387
# Epoch 37/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.8710
# Epoch 38/40
# 12/12 [==============================] - 2s 152ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.8387
# Epoch 39/40
# 12/12 [==============================] - 2s 151ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.8710
# Epoch 40/40
# 12/12 [==============================] - 2s 150ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2745 - val_accuracy: 0.8710

# %%
print(label)
# Out:
# /content/drive/MyDrive/parkinson/HC/HCteta_8.png

# %%
net.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 14,747,650
# Trainable params: 14,747,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(net)

# %%
net.save("net.h5")

# %%
plt.style.use("ggplot")
plt.plot(H.history["accuracy"],label="train")
plt.plot(H.history["val_accuracy"],label="test")
plt.plot(H.history["loss"],label="train loss")
plt.plot(H.history["val_loss"],label="test loss")
plt.legend()
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.title("Parkinson classification using VGG-16")
plt.show()
